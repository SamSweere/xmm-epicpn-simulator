# %%
import os
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdu = fits.open('/home/sam/Documents/ESA/programs/sixte/share/sixte/instruments/xmm/epicpn/pn_psf_str_1.0_v.1.3.fits')

# %%
hdu.info()
# Out:
# Filename: /home/sam/Documents/ESA/programs/sixte/share/sixte/instruments/xmm/epicpn/pn_psf_str_1.0_v.1.3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  300eVthet0arcsecphi0deg    1 PrimaryHDU      46   (300, 300)   float64
#   1  300eVthet0arcsecphi4deg    1 ImageHDU        72   (300, 300)   float64
#   2  300eVthet0arcsecphi8deg    1 ImageHDU        72   (300, 300)   float64
#   3  300eVthet0arcsecphi12deg    1 ImageHDU        72   (300, 300)   float64
#   4  300eVthet0arcsecphi16deg    1 ImageHDU        72   (300, 300)   float64
#   5  300eVthet0arcsecphi20deg    1 ImageHDU        72   (300, 300)   float64
#   6  300eVthet0arcsecphi24deg    1 ImageHDU        72   (300, 300)   float64
#   7  300eVthet0arcsecphi28deg    1 ImageHDU        72   (300, 300)   float64
#   8  300eVthet0arcsecphi32deg    1 ImageHDU        72   (300, 300)   float64
#   9  300eVthet0arcsecphi36deg    1 ImageHDU        72   (300, 300)   float64
# ...

# %%
data = hdu['300eVthet1200arcsecphi12deg'].data

# %%
plt.imshow(np.log(data))

# %%
hdu_small = fits.open('/home/sam/Documents/ESA/xmm_simulation/other/psf_gen/pn_psf_small_str_1.0_e_0.5_2.0_kev_v.1.3.fits')

# %%
hdu_small.info()
# Out:
# Filename: /home/sam/Documents/ESA/xmm_simulation/other/psf_gen/pn_psf_small_str_1.0_e_0.5_2.0_kev_v.1.3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  500eVthet0arcsecphi0deg    1 PrimaryHDU      46   (120, 120)   float64
#   1  500eVthet0arcsecphi8deg    1 ImageHDU        72   (120, 120)   float64
#   2  500eVthet0arcsecphi16deg    1 ImageHDU        72   (120, 120)   float64
#   3  500eVthet0arcsecphi24deg    1 ImageHDU        72   (120, 120)   float64
#   4  500eVthet0arcsecphi32deg    1 ImageHDU        72   (120, 120)   float64
#   5  500eVthet0arcsecphi40deg    1 ImageHDU        72   (120, 120)   float64
#   6  500eVthet0arcsecphi48deg    1 ImageHDU        72   (120, 120)   float64
#   7  500eVthet0arcsecphi56deg    1 ImageHDU        72   (120, 120)   float64
#   8  500eVthet0arcsecphi64deg    1 ImageHDU        72   (120, 120)   float64
#   9  500eVthet0arcsecphi72deg    1 ImageHDU        72   (120, 120)   float64
# ...

# %%
data = hdu_small['2000eVthet1200arcsecphi344deg'].data

# %%
plt.imshow(data)

# %%
plt.imshow(np.log(data))
